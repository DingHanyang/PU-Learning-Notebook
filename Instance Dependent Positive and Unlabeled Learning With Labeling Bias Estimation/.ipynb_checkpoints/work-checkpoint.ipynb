# %%
import torch
import torch.optim as optim
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

column_names = ['variance', 'skewness', 'curtosis', 'entropy', 'class']
data = pd.read_csv('./code/data/banknote.txt', names=column_names)

x = data.drop('class', axis=1)
y = data['class']

logistic_model = LogisticRegression() 

logistic_model.fit(x, y)

y_pred = logistic_model.predict(x)

accuracy = accuracy_score(y, y_pred)
print(f'Accuracy of the logistic regression model: {accuracy:.2f}')

print('Model coefficients (θ):', logistic_model.coef_) # Theta
print('Model intercept (θ0):', logistic_model.intercept_)
# Out:
# Accuracy of the logistic regression model: 0.99
# Model coefficients (θ): [[-3.36496558 -1.88765064 -2.30699401 -0.08893876]]
# Model intercept (θ0): [3.73883455]

# %%
def strategy1(x,theta_lgt,k):
    eta_x = (1 + np.exp(-np.dot(theta_lgt.T, x)))**(-1/k)
    return eta_x

def strategy2(x,theta_lgt,k):
    eta_x = 1 - strategy1(x,theta_lgt,k)
    return eta_x

# %%
x_values = x.values

k = 10
pi = 0.3
data['eta'] = [strategy1(x_i, theta_lgt, k) for x_i in x_values]

data_with_pu_label = data.sort_values(by='eta', ascending=False)

P_num = sum(data_with_pu_label['class']==0)

# 选择前 (1-pi)*正例 的样本作为正例
data_with_pu_label['pu_label'] = 0  # 创建一个新列以存储 PU 标签
data_with_pu_label.iloc[:int((1-pi)*P_num), -1] = 1  # 前设置为观测到的正例 即 s = 1

data_group = data_with_pu_label.groupby('pu_label')
S_P = data_group.get_group(1)
S_U = data_group.get_group(0)

# %%
S_P = S_P.iloc[:, :4]
S_P['y1'] = 1
S_P['y0'] = 0
S_P['si'] = 1
S_P['yi'] = 1

S_U = S_U.iloc[:, :4]
S_U['y1'] = 0 # 这里S_U在进入EM算法前应该根据已初始化的theta值，计算出widetilde{P(y_i)}的值
S_U['y0'] = 0
S_U['si'] = 0
S_U['yi'] = 3 # 用3 表示 Unknown





xi_SU = torch.tensor(S_U.drop(['y1','y0','si','yi'], axis=1).values, dtype=torch.float32)
y1_SU = torch.tensor(S_U['y1'].values, dtype=torch.int64)
y0_SU = torch.tensor(S_U['y0'].values, dtype=torch.int64)
si_SU = torch.tensor(S_U['si'].values, dtype=torch.int64)
yi_SU = torch.tensor(S_U['yi'].values, dtype=torch.int64)



S_U = [[xi_SU[i], y1_SU[i],y0_SU[i],si_SU[i],yi_SU[i]] for i in range(len(S_U))]

xi_SP = torch.tensor(S_P.drop(['y1','y0','si','yi'], axis=1).values, dtype=torch.float32)
y1_SP = torch.tensor(S_P['y1'].values, dtype=torch.int64)
y0_SP = torch.tensor(S_P['y0'].values, dtype=torch.int64)
si_SP = torch.tensor(S_P['si'].values, dtype=torch.int64)
yi_SP = torch.tensor(S_P['yi'].values, dtype=torch.int64)



S_P = [[xi_SP[i], y1_SP[i],y0_SP[i],si_SP[i],yi_SP[i]] for i in range(len(S_P))]

# %%
# init theta1 theta2

x = data_with_pu_label.iloc[:, :4]
y = data_with_pu_label['pu_label']

logistic_model = LogisticRegression()
logistic_model.fit(x, y)

theta1 = torch.tensor(logistic_model.coef_[0],dtype=torch.float32)
theta2 = torch.zeros(4,dtype=torch.float32)

# %%
theta1,theta2
# Out:
# (tensor([-5.1460, -2.5416, -3.2544, -0.0520]), tensor([0., 0., 0., 0.]))

# %%
import torch
import torch.optim as optim

class PU_EM_Model:
    def __init__(self, theta1, theta2, S_U, S_P):
        """
        dataset = [x_i(4D),y_1,y_0,s_i]
        """

        self.S_U = S_U
        self.S_P = S_P
        self.dataset = S_U + S_P
        self.theta1 = theta1.clone().detach().requires_grad_(True)
        self.theta2 = theta2.clone().detach().requires_grad_(True)

    def _logistic_function(self, theta, x):
        # logistic function
        return 1.0 / (1.0 + torch.exp(-torch.matmul(theta.T, x)))

    def eta(self, x):
        # 公式(8)
        return self._logistic_function(self.theta2, x)

    def h(self, x):
        # 公式(9)
        return self._logistic_function(self.theta1, x)

    def grad_expressions_theta1(self):
        grad_theta1 = torch.zeros_like(self.theta1)
        for data in self.dataset:
            x = data[0]
            y_1 = data[1]
            y_0 = data[2]

            h_x = self.h(x)
            grad_theta1 += y_1 * (h_x - 1) * x + y_0 * h_x * x
        return grad_theta1

    def grad_expressions_theta2(self):
        grad_theta2 = torch.zeros_like(self.theta2)
        for data in self.dataset:
            x = data[0]
            y_1 = data[1]
            y_0 = data[2]
            s = data[3]

            if not s.item():
                # s 为 0的情况下
                grad_theta2 += y_1 * self.eta(x)
            else:
                # s 为 1的情况下
                grad_theta2 += y_1 * (self.eta(x) - 1)

        return grad_theta2

    def expectation_step(self):
        # 在E步中更新隐变量的期望
        for i in range(len(self.dataset)):
            # 为了可读性
            x = self.dataset[i][0]
            s = self.dataset[i][3]

            if not s.item():
                # s 为 0的情况下 ,通过公式(12)对\cap{P(y)}的值进行更新
                p_y1 = (1 - self.eta(x)) * self.h(x)
                p_y0 = 1 - self.h(x)
                # 更新数据集中的 y_1 和 y_0
                self.dataset[i][1] = p_y1
                self.dataset[i][2] = p_y0
            else:
                # s 为 1的情况下
                p_y1 = self.eta(x) * self.h(x)
                p_y0 = 0
                # 更新数据集中的 y_1 和 y_0
                self.dataset[i][1] = p_y1  # 1
                self.dataset[i][2] = p_y0  # 0

    def maximization_step(self, optimizer):
        # 在M步中更新参数 theta1 和 theta2
        optimizer.zero_grad()
        # 计算梯度表达式
        self.theta1.grad = self.grad_expressions_theta1()  # 计算 theta1 的梯度
        self.theta2.grad = self.grad_expressions_theta2()  # 计算 theta2 的梯度
        optimizer.step()


# 定义优化器参数
lr = 0.01  # 学习率
rho1 = 0.9  # beta1，用于一阶矩估计的衰减率
rho2 = 0.999  # beta2，用于二阶矩估计的衰减率
num_epochs = 100

model = PU_EM_Model(theta1, theta2, S_U, S_P)
optimizer = optim.Adam([model.theta1, model.theta2], lr=lr)

for epoch in range(num_epochs):
    # E步
    model.expectation_step()

    # M步
    model.maximization_step(optimizer)

    # 输出当前参数
    print(f'Epoch [{epoch + 1}/{num_epochs}], theta1: {model.theta1}, theta2: {model.theta2}')
# Out:
# Epoch [1/100], theta1: tensor([-5.1560, -2.5516, -3.2444, -0.0620], requires_grad=True), theta2: tensor([0.0100, 0.0100, 0.0100, 0.0100], requires_grad=True)
# Epoch [2/100], theta1: tensor([-5.1658, -2.5610, -3.2351, -0.0719], requires_grad=True), theta2: tensor([0.0200, 0.0200, 0.0200, 0.0200], requires_grad=True)
# Epoch [3/100], theta1: tensor([-5.1752, -2.5688, -3.2277, -0.0819], requires_grad=True), theta2: tensor([0.0300, 0.0300, 0.0300, 0.0300], requires_grad=True)
# Epoch [4/100], theta1: tensor([-5.1840, -2.5739, -3.2235, -0.0918], requires_grad=True), theta2: tensor([0.0400, 0.0400, 0.0400, 0.0400], requires_grad=True)
# Epoch [5/100], theta1: tensor([-5.1920, -2.5761, -3.2225, -0.1016], requires_grad=True), theta2: tensor([0.0500, 0.0500, 0.0500, 0.0500], requires_grad=True)
# Epoch [6/100], theta1: tensor([-5.1994, -2.5759, -3.2241, -0.1113], requires_grad=True), theta2: tensor([0.0600, 0.0600, 0.0600, 0.0600], requires_grad=True)
# Epoch [7/100], theta1: tensor([-5.2063, -2.5741, -3.2273, -0.1209], requires_grad=True), theta2: tensor([0.0700, 0.0700, 0.0700, 0.0700], requires_grad=True)
# Epoch [8/100], theta1: tensor([-5.2128, -2.5712, -3.2316, -0.1303], requires_grad=True), theta2: tensor([0.0800, 0.0800, 0.0800, 0.0800], requires_grad=True)
# Epoch [9/100], theta1: tensor([-5.2192, -2.5678, -3.2365, -0.1393], requires_grad=True), theta2: tensor([0.0900, 0.0900, 0.0900, 0.0900], requires_grad=True)
# Epoch [10/100], theta1: tensor([-5.2256, -2.5644, -3.2417, -0.1480], requires_grad=True), theta2: tensor([0.1000, 0.1000, 0.1000, 0.1000], requires_grad=True)
# Epoch [11/100], theta1: tensor([-5.2323, -2.5614, -3.2466, -0.1563], requires_grad=True), theta2: tensor([0.1099, 0.1099, 0.1099, 0.1099], requires_grad=True)
# Epoch [12/100], theta1: tensor([-5.2392, -2.5591, -3.2511, -0.1642], requires_grad=True), theta2: tensor([0.1199, 0.1199, 0.1199, 0.1199], requires_grad=True)
# Epoch [13/100], theta1: tensor([-5.2465, -2.5579, -3.2549, -0.1715], requires_grad=True), theta2: tensor([0.1299, 0.1299, 0.1299, 0.1299], requires_grad=True)
# Epoch [14/100], theta1: tensor([-5.2541, -2.5579, -3.2578, -0.1782], requires_grad=True), theta2: tensor([0.1398, 0.1398, 0.1398, 0.1398], requires_grad=True)
# Epoch [15/100], theta1: tensor([-5.2620, -2.5589, -3.2600, -0.1843], requires_grad=True), theta2: tensor([0.1498, 0.1498, 0.1498, 0.1498], requires_grad=True)
# Epoch [16/100], theta1: tensor([-5.2701, -2.5609, -3.2614, -0.1898], requires_grad=True), theta2: tensor([0.1597, 0.1597, 0.1597, 0.1597], requires_grad=True)
# Epoch [17/100], theta1: tensor([-5.2784, -2.5636, -3.2623, -0.1947], requires_grad=True), theta2: tensor([0.1697, 0.1697, 0.1697, 0.1697], requires_grad=True)
# Epoch [18/100], theta1: tensor([-5.2867, -2.5668, -3.2629, -0.1989], requires_grad=True), theta2: tensor([0.1796, 0.1796, 0.1796, 0.1796], requires_grad=True)
# Epoch [19/100], theta1: tensor([-5.2950, -2.5703, -3.2635, -0.2025], requires_grad=True), theta2: tensor([0.1895, 0.1895, 0.1895, 0.1895], requires_grad=True)
# Epoch [20/100], theta1: tensor([-5.3032, -2.5737, -3.2643, -0.2054], requires_grad=True), theta2: tensor([0.1993, 0.1993, 0.1993, 0.1993], requires_grad=True)
# Epoch [21/100], theta1: tensor([-5.3112, -2.5771, -3.2655, -0.2078], requires_grad=True), theta2: tensor([0.2092, 0.2092, 0.2092, 0.2092], requires_grad=True)
# Epoch [22/100], theta1: tensor([-5.3189, -2.5801, -3.2672, -0.2096], requires_grad=True), theta2: tensor([0.2190, 0.2190, 0.2190, 0.2190], requires_grad=True)
# Epoch [23/100], theta1: tensor([-5.3264, -2.5827, -3.2694, -0.2109], requires_grad=True), theta2: tensor([0.2288, 0.2288, 0.2288, 0.2288], requires_grad=True)
# Epoch [24/100], theta1: tensor([-5.3335, -2.5849, -3.2723, -0.2116], requires_grad=True), theta2: tensor([0.2386, 0.2386, 0.2386, 0.2386], requires_grad=True)
# Epoch [25/100], theta1: tensor([-5.3404, -2.5867, -3.2758, -0.2118], requires_grad=True), theta2: tensor([0.2484, 0.2484, 0.2484, 0.2484], requires_grad=True)
# Epoch [26/100], theta1: tensor([-5.3470, -2.5882, -3.2797, -0.2115], requires_grad=True), theta2: tensor([0.2582, 0.2582, 0.2582, 0.2582], requires_grad=True)
# Epoch [27/100], theta1: tensor([-5.3534, -2.5894, -3.2841, -0.2107], requires_grad=True), theta2: tensor([0.2679, 0.2679, 0.2679, 0.2679], requires_grad=True)
# Epoch [28/100], theta1: tensor([-5.3597, -2.5905, -3.2886, -0.2095], requires_grad=True), theta2: tensor([0.2776, 0.2776, 0.2776, 0.2776], requires_grad=True)
# Epoch [29/100], theta1: tensor([-5.3658, -2.5916, -3.2933, -0.2079], requires_grad=True), theta2: tensor([0.2872, 0.2872, 0.2872, 0.2872], requires_grad=True)
# Epoch [30/100], theta1: tensor([-5.3720, -2.5929, -3.2980, -0.2058], requires_grad=True), theta2: tensor([0.2968, 0.2968, 0.2968, 0.2968], requires_grad=True)
# Epoch [31/100], theta1: tensor([-5.3782, -2.5945, -3.3026, -0.2034], requires_grad=True), theta2: tensor([0.3064, 0.3064, 0.3064, 0.3064], requires_grad=True)
# Epoch [32/100], theta1: tensor([-5.3845, -2.5964, -3.3069, -0.2006], requires_grad=True), theta2: tensor([0.3160, 0.3160, 0.3160, 0.3160], requires_grad=True)
# Epoch [33/100], theta1: tensor([-5.3909, -2.5987, -3.3111, -0.1975], requires_grad=True), theta2: tensor([0.3255, 0.3255, 0.3255, 0.3255], requires_grad=True)
# Epoch [34/100], theta1: tensor([-5.3974, -2.6014, -3.3149, -0.1941], requires_grad=True), theta2: tensor([0.3350, 0.3350, 0.3350, 0.3350], requires_grad=True)
# Epoch [35/100], theta1: tensor([-5.4040, -2.6045, -3.3186, -0.1904], requires_grad=True), theta2: tensor([0.3445, 0.3445, 0.3445, 0.3445], requires_grad=True)
# Epoch [36/100], theta1: tensor([-5.4107, -2.6079, -3.3220, -0.1865], requires_grad=True), theta2: tensor([0.3539, 0.3539, 0.3539, 0.3539], requires_grad=True)
# Epoch [37/100], theta1: tensor([-5.4174, -2.6116, -3.3252, -0.1823], requires_grad=True), theta2: tensor([0.3632, 0.3632, 0.3632, 0.3632], requires_grad=True)
# Epoch [38/100], theta1: tensor([-5.4242, -2.6153, -3.3285, -0.1781], requires_grad=True), theta2: tensor([0.3726, 0.3726, 0.3726, 0.3726], requires_grad=True)
# Epoch [39/100], theta1: tensor([-5.4309, -2.6192, -3.3317, -0.1736], requires_grad=True), theta2: tensor([0.3819, 0.3819, 0.3819, 0.3819], requires_grad=True)
# Epoch [40/100], theta1: tensor([-5.4376, -2.6230, -3.3351, -0.1691], requires_grad=True), theta2: tensor([0.3911, 0.3911, 0.3911, 0.3911], requires_grad=True)
# Epoch [41/100], theta1: tensor([-5.4442, -2.6267, -3.3386, -0.1644], requires_grad=True), theta2: tensor([0.4004, 0.4004, 0.4004, 0.4004], requires_grad=True)
# Epoch [42/100], theta1: tensor([-5.4507, -2.6302, -3.3423, -0.1597], requires_grad=True), theta2: tensor([0.4095, 0.4095, 0.4095, 0.4095], requires_grad=True)
# Epoch [43/100], theta1: tensor([-5.4571, -2.6336, -3.3462, -0.1550], requires_grad=True), theta2: tensor([0.4187, 0.4187, 0.4187, 0.4187], requires_grad=True)
# Epoch [44/100], theta1: tensor([-5.4635, -2.6368, -3.3504, -0.1502], requires_grad=True), theta2: tensor([0.4278, 0.4278, 0.4278, 0.4278], requires_grad=True)
# Epoch [45/100], theta1: tensor([-5.4697, -2.6398, -3.3547, -0.1453], requires_grad=True), theta2: tensor([0.4368, 0.4368, 0.4368, 0.4368], requires_grad=True)
# Epoch [46/100], theta1: tensor([-5.4759, -2.6427, -3.3593, -0.1405], requires_grad=True), theta2: tensor([0.4458, 0.4458, 0.4458, 0.4458], requires_grad=True)
# Epoch [47/100], theta1: tensor([-5.4821, -2.6455, -3.3639, -0.1357], requires_grad=True), theta2: tensor([0.4548, 0.4548, 0.4548, 0.4548], requires_grad=True)
# Epoch [48/100], theta1: tensor([-5.4882, -2.6483, -3.3685, -0.1308], requires_grad=True), theta2: tensor([0.4637, 0.4637, 0.4637, 0.4637], requires_grad=True)
# Epoch [49/100], theta1: tensor([-5.4944, -2.6511, -3.3732, -0.1260], requires_grad=True), theta2: tensor([0.4726, 0.4726, 0.4726, 0.4726], requires_grad=True)
# Epoch [50/100], theta1: tensor([-5.5006, -2.6540, -3.3778, -0.1212], requires_grad=True), theta2: tensor([0.4814, 0.4814, 0.4814, 0.4814], requires_grad=True)
# Epoch [51/100], theta1: tensor([-5.5069, -2.6570, -3.3823, -0.1165], requires_grad=True), theta2: tensor([0.4902, 0.4902, 0.4902, 0.4902], requires_grad=True)
# Epoch [52/100], theta1: tensor([-5.5132, -2.6601, -3.3867, -0.1118], requires_grad=True), theta2: tensor([0.4990, 0.4990, 0.4990, 0.4990], requires_grad=True)
# Epoch [53/100], theta1: tensor([-5.5197, -2.6634, -3.3910, -0.1071], requires_grad=True), theta2: tensor([0.5077, 0.5077, 0.5077, 0.5077], requires_grad=True)
# Epoch [54/100], theta1: tensor([-5.5262, -2.6668, -3.3951, -0.1024], requires_grad=True), theta2: tensor([0.5164, 0.5164, 0.5164, 0.5164], requires_grad=True)
# Epoch [55/100], theta1: tensor([-5.5327, -2.6703, -3.3992, -0.0978], requires_grad=True), theta2: tensor([0.5250, 0.5250, 0.5250, 0.5250], requires_grad=True)
# Epoch [56/100], theta1: tensor([-5.5393, -2.6738, -3.4032, -0.0933], requires_grad=True), theta2: tensor([0.5336, 0.5336, 0.5336, 0.5336], requires_grad=True)
# Epoch [57/100], theta1: tensor([-5.5460, -2.6774, -3.4072, -0.0888], requires_grad=True), theta2: tensor([0.5421, 0.5421, 0.5421, 0.5421], requires_grad=True)
# Epoch [58/100], theta1: tensor([-5.5526, -2.6810, -3.4111, -0.0844], requires_grad=True), theta2: tensor([0.5506, 0.5506, 0.5506, 0.5506], requires_grad=True)
# Epoch [59/100], theta1: tensor([-5.5593, -2.6846, -3.4151, -0.0800], requires_grad=True), theta2: tensor([0.5591, 0.5591, 0.5591, 0.5591], requires_grad=True)
# Epoch [60/100], theta1: tensor([-5.5660, -2.6881, -3.4192, -0.0757], requires_grad=True), theta2: tensor([0.5675, 0.5675, 0.5675, 0.5675], requires_grad=True)
# Epoch [61/100], theta1: tensor([-5.5726, -2.6915, -3.4233, -0.0715], requires_grad=True), theta2: tensor([0.5759, 0.5759, 0.5759, 0.5759], requires_grad=True)
# Epoch [62/100], theta1: tensor([-5.5792, -2.6948, -3.4275, -0.0673], requires_grad=True), theta2: tensor([0.5842, 0.5842, 0.5842, 0.5842], requires_grad=True)
# Epoch [63/100], theta1: tensor([-5.5859, -2.6981, -3.4318, -0.0632], requires_grad=True), theta2: tensor([0.5925, 0.5925, 0.5925, 0.5925], requires_grad=True)
# Epoch [64/100], theta1: tensor([-5.5925, -2.7012, -3.4361, -0.0592], requires_grad=True), theta2: tensor([0.6008, 0.6008, 0.6008, 0.6008], requires_grad=True)
# Epoch [65/100], theta1: tensor([-5.5991, -2.7043, -3.4405, -0.0552], requires_grad=True), theta2: tensor([0.6090, 0.6090, 0.6090, 0.6090], requires_grad=True)
# Epoch [66/100], theta1: tensor([-5.6056, -2.7074, -3.4449, -0.0513], requires_grad=True), theta2: tensor([0.6172, 0.6172, 0.6172, 0.6172], requires_grad=True)
# Epoch [67/100], theta1: tensor([-5.6123, -2.7104, -3.4494, -0.0475], requires_grad=True), theta2: tensor([0.6253, 0.6253, 0.6253, 0.6253], requires_grad=True)
# Epoch [68/100], theta1: tensor([-5.6189, -2.7134, -3.4538, -0.0437], requires_grad=True), theta2: tensor([0.6334, 0.6334, 0.6334, 0.6334], requires_grad=True)
# Epoch [69/100], theta1: tensor([-5.6256, -2.7165, -3.4582, -0.0399], requires_grad=True), theta2: tensor([0.6415, 0.6415, 0.6415, 0.6415], requires_grad=True)
# Epoch [70/100], theta1: tensor([-5.6323, -2.7196, -3.4625, -0.0363], requires_grad=True), theta2: tensor([0.6495, 0.6495, 0.6495, 0.6495], requires_grad=True)
# Epoch [71/100], theta1: tensor([-5.6390, -2.7227, -3.4668, -0.0326], requires_grad=True), theta2: tensor([0.6575, 0.6575, 0.6575, 0.6575], requires_grad=True)
# Epoch [72/100], theta1: tensor([-5.6458, -2.7259, -3.4711, -0.0290], requires_grad=True), theta2: tensor([0.6655, 0.6655, 0.6655, 0.6655], requires_grad=True)
# Epoch [73/100], theta1: tensor([-5.6526, -2.7291, -3.4753, -0.0255], requires_grad=True), theta2: tensor([0.6734, 0.6734, 0.6734, 0.6734], requires_grad=True)
# Epoch [74/100], theta1: tensor([-5.6594, -2.7324, -3.4794, -0.0219], requires_grad=True), theta2: tensor([0.6813, 0.6813, 0.6813, 0.6813], requires_grad=True)
# Epoch [75/100], theta1: tensor([-5.6663, -2.7357, -3.4835, -0.0185], requires_grad=True), theta2: tensor([0.6892, 0.6892, 0.6892, 0.6892], requires_grad=True)
# Epoch [76/100], theta1: tensor([-5.6731, -2.7390, -3.4877, -0.0150], requires_grad=True), theta2: tensor([0.6970, 0.6970, 0.6970, 0.6970], requires_grad=True)
# Epoch [77/100], theta1: tensor([-5.6800, -2.7422, -3.4918, -0.0116], requires_grad=True), theta2: tensor([0.7047, 0.7047, 0.7047, 0.7047], requires_grad=True)
# Epoch [78/100], theta1: tensor([-5.6869, -2.7455, -3.4959, -0.0083], requires_grad=True), theta2: tensor([0.7125, 0.7125, 0.7125, 0.7125], requires_grad=True)
# Epoch [79/100], theta1: tensor([-5.6938e+00, -2.7487e+00, -3.5001e+00, -4.9610e-03],
#        requires_grad=True), theta2: tensor([0.7202, 0.7202, 0.7202, 0.7202], requires_grad=True)
# Epoch [80/100], theta1: tensor([-5.7006e+00, -2.7519e+00, -3.5043e+00, -1.6691e-03],
#        requires_grad=True), theta2: tensor([0.7279, 0.7279, 0.7279, 0.7279], requires_grad=True)
# Epoch [81/100], theta1: tensor([-5.7075e+00, -2.7550e+00, -3.5085e+00,  1.5917e-03],
#        requires_grad=True), theta2: tensor([0.7355, 0.7355, 0.7355, 0.7355], requires_grad=True)
# Epoch [82/100], theta1: tensor([-5.7144e+00, -2.7581e+00, -3.5128e+00,  4.8229e-03],
#        requires_grad=True), theta2: tensor([0.7432, 0.7432, 0.7432, 0.7432], requires_grad=True)
# Epoch [83/100], theta1: tensor([-5.7212, -2.7612, -3.5170,  0.0080], requires_grad=True), theta2: tensor([0.7507, 0.7507, 0.7507, 0.7507], requires_grad=True)
# Epoch [84/100], theta1: tensor([-5.7281, -2.7642, -3.5213,  0.0112], requires_grad=True), theta2: tensor([0.7583, 0.7583, 0.7583, 0.7583], requires_grad=True)
# Epoch [85/100], theta1: tensor([-5.7349, -2.7672, -3.5256,  0.0144], requires_grad=True), theta2: tensor([0.7658, 0.7658, 0.7658, 0.7658], requires_grad=True)
# Epoch [86/100], theta1: tensor([-5.7418, -2.7703, -3.5299,  0.0175], requires_grad=True), theta2: tensor([0.7733, 0.7733, 0.7733, 0.7733], requires_grad=True)
# Epoch [87/100], theta1: tensor([-5.7486, -2.7733, -3.5342,  0.0206], requires_grad=True), theta2: tensor([0.7808, 0.7808, 0.7808, 0.7808], requires_grad=True)
# Epoch [88/100], theta1: tensor([-5.7555, -2.7764, -3.5385,  0.0237], requires_grad=True), theta2: tensor([0.7882, 0.7882, 0.7882, 0.7882], requires_grad=True)
# Epoch [89/100], theta1: tensor([-5.7624, -2.7794, -3.5427,  0.0268], requires_grad=True), theta2: tensor([0.7956, 0.7956, 0.7956, 0.7956], requires_grad=True)
# Epoch [90/100], theta1: tensor([-5.7693, -2.7825, -3.5470,  0.0298], requires_grad=True), theta2: tensor([0.8030, 0.8030, 0.8030, 0.8030], requires_grad=True)
# Epoch [91/100], theta1: tensor([-5.7762, -2.7856, -3.5512,  0.0329], requires_grad=True), theta2: tensor([0.8103, 0.8103, 0.8103, 0.8103], requires_grad=True)
# Epoch [92/100], theta1: tensor([-5.7831, -2.7887, -3.5554,  0.0359], requires_grad=True), theta2: tensor([0.8177, 0.8177, 0.8177, 0.8177], requires_grad=True)
# Epoch [93/100], theta1: tensor([-5.7901, -2.7919, -3.5596,  0.0389], requires_grad=True), theta2: tensor([0.8250, 0.8250, 0.8250, 0.8250], requires_grad=True)
# Epoch [94/100], theta1: tensor([-5.7970, -2.7950, -3.5637,  0.0419], requires_grad=True), theta2: tensor([0.8322, 0.8322, 0.8322, 0.8322], requires_grad=True)
# Epoch [95/100], theta1: tensor([-5.8039, -2.7981, -3.5679,  0.0449], requires_grad=True), theta2: tensor([0.8395, 0.8395, 0.8395, 0.8395], requires_grad=True)
# Epoch [96/100], theta1: tensor([-5.8108, -2.8013, -3.5721,  0.0479], requires_grad=True), theta2: tensor([0.8467, 0.8467, 0.8467, 0.8467], requires_grad=True)
# Epoch [97/100], theta1: tensor([-5.8178, -2.8044, -3.5763,  0.0508], requires_grad=True), theta2: tensor([0.8539, 0.8539, 0.8539, 0.8539], requires_grad=True)
# Epoch [98/100], theta1: tensor([-5.8247, -2.8075, -3.5805,  0.0538], requires_grad=True), theta2: tensor([0.8610, 0.8610, 0.8610, 0.8610], requires_grad=True)
# Epoch [99/100], theta1: tensor([-5.8316, -2.8106, -3.5847,  0.0567], requires_grad=True), theta2: tensor([0.8682, 0.8682, 0.8682, 0.8682], requires_grad=True)
# Epoch [100/100], theta1: tensor([-5.8385, -2.8137, -3.5889,  0.0597], requires_grad=True), theta2: tensor([0.8753, 0.8753, 0.8753, 0.8753], requires_grad=True)

# %%
# 测试
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score

column_names = ['variance', 'skewness', 'curtosis', 'entropy', 'class']
data = pd.read_csv('./code/data/banknote.txt', names=column_names)

x = data.drop('class', axis=1).values
y = data['class'].values



theta = np.array([-5.8385, -2.8137, -3.5889,  0.0597]) 
theta_0 = 0

z = 1/(np.exp(-np.dot(x, theta))+1)

y_pred = (z -0.5 > 0).astype(int)


accuracy = accuracy_score(y, y_pred)
print(f'Accuracy of the manually defined logistic regression model: {accuracy:.2f}')

# 显示手动设置的参数
print('Manually defined model coefficients (θ):', theta)
# Out:
# Accuracy of the manually defined logistic regression model: 0.94
# Manually defined model coefficients (θ): [-5.8385 -2.8137 -3.5889  0.0597]
